# %%
#Import
import json
import pandas as pd
import numpy as np

# %%
#Path

# %%
#Option
pd.set_option("display.max_rows", None, 
              "display.max_columns", None)

# %%
#Import Data
with open('5398647788global.json') as matchglobal:
     matchglobal = json.load(matchglobal)
with open('5398647788timeline.json') as matchtimeline:
     matchtimeline = json.load(matchtimeline)

# %%
COLUMN_NAMES = ["match_ID","timeline","who_win",
                "blue_kill_nashor","blue_kill_fire_drake","blue_kill_air_drake","blue_kill_water_drake","blue_kill_earth_drake","blue_kill_ancient_drake","blue_soul_drake","blue_destr_tower","blue_gold",
                "red_kill_nashor","red_kill_fire_drake","red_kill_air_drake","red_kill_water_drake","red_kill_earth_drake","red_kill_ancient_drake","red_soul_drake","red_destr_tower","red_gold",
                "lane_1","champion_1","level_1","kill_1","death_1","assist_1","item1_1","item2_1","item3_1","item4_1","item5_1","item6_1","trinket_1",
                "lane_2","champion_2","level_2","kill_2","death_2","assist_2","item1_2","item2_2","item3_2","item4_2","item5_2","item6_2","trinket_2",
                "lane_3","champion_3","level_3","kill_3","death_3","assist_3","item1_3","item2_3","item3_3","item4_3","item5_3","item6_3","trinket_3",
                "lane_4","champion_4","level_4","kill_4","death_4","assist_4","item1_4","item2_4","item3_4","item4_4","item5_4","item6_4","trinket_4",
                "lane_5","champion_5","level_5","kill_5","death_5","assist_5","item1_5","item2_5","item3_5","item4_5","item5_5","item6_5","trinket_5",
                "lane_6","champion_6","level_6","kill_6","death_6","assist_6","item1_6","item2_6","item3_6","item4_6","item5_6","item6_6","trinket_6",
                "lane_7","champion_7","level_7","kill_7","death_7","assist_7","item1_7","item2_7","item3_7","item4_7","item5_7","item6_7","trinket_7",
                "lane_8","champion_8","level_8","kill_8","death_8","assist_8","item1_8","item2_8","item3_8","item4_8","item5_8","item6_8","trinket_8",
                "lane_9","champion_9","level_9","kill_9","death_9","assist_9","item1_9","item2_9","item3_9","item4_9","item5_9","item6_9","trinket_9",
                "lane_10","champion_10","level_10","kill_10","death_10","assist_10","item1_10","item2_10","item3_10","item4_10","item5_10","item6_10","trinket_10"]
df = pd.DataFrame(columns=COLUMN_NAMES)

for i in range (len(matchtimeline["frames"])):
    df.loc[i] = row = [np.nan,f"{i}"]+list([np.nan]*149)

df["match_ID"] = matchglobal["gameId"]

if matchglobal["teams"][0]["win"] == "Win":
    who_win = "Blue"
else :
    who_win = "Red"
df["who_win"] = who_win

# %%
df
# Out:
#       match_ID timeline who_win blue_kill_nashor blue_kill_fire_drake  \
# 0   5398647788        0    Blue              NaN                  NaN
# 1   5398647788        1    Blue              NaN                  NaN
# 2   5398647788        2    Blue              NaN                  NaN
# 3   5398647788        3    Blue              NaN                  NaN
# 4   5398647788        4    Blue              NaN                  NaN
# 5   5398647788        5    Blue              NaN                  NaN
# 6   5398647788        6    Blue              NaN                  NaN
# 7   5398647788        7    Blue              NaN                  NaN
# 8   5398647788        8    Blue              NaN                  NaN
# 9   5398647788        9    Blue              NaN                  NaN
# 10  5398647788       10    Blue              NaN                  NaN
# 11  5398647788       11    Blue              NaN                  NaN
# ...

# %%
matchglobal["participants"][2]["championId"]
# Out:
# 104

# %%
for i in range (0,9,1):
    participantID = matchglobal["participants"][i]["participantId"]
    championID = matchglobal["participants"][i]["championId"]
    df[f"champion_{participantID}"] = f'{championID}'
df
# Out:
#       match_ID timeline who_win blue_kill_nashor blue_kill_fire_drake  \
# 0   5398647788        0    Blue              NaN                  NaN
# 1   5398647788        1    Blue              NaN                  NaN
# 2   5398647788        2    Blue              NaN                  NaN
# 3   5398647788        3    Blue              NaN                  NaN
# 4   5398647788        4    Blue              NaN                  NaN
# 5   5398647788        5    Blue              NaN                  NaN
# 6   5398647788        6    Blue              NaN                  NaN
# 7   5398647788        7    Blue              NaN                  NaN
# 8   5398647788        8    Blue              NaN                  NaN
# 9   5398647788        9    Blue              NaN                  NaN
# 10  5398647788       10    Blue              NaN                  NaN
# 11  5398647788       11    Blue              NaN                  NaN
# ...
